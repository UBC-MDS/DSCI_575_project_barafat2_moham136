# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_core.messages import HumanMessage, SystemMessage
# Out:
# c:\Users\moham\miniforge3\envs\dsci-575-project\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # loads variables from .env into environment

token = os.getenv("HF_TOKEN")

# %%
# Set up the endpoint
llm_endpoint = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct",
    task="text-generation",
    max_new_tokens=100,
    provider="auto"
)

# Wrap it as a chat model
llm = ChatHuggingFace(llm=llm_endpoint)

# Use it with messages
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is machine learning?")
]

response = llm.invoke(messages)
print(response.content)
# Out:
# Machine learning is a subset of artificial intelligence (AI) that involves the use of algorithms and statistical models to enable machines to learn from data, make decisions, and improve their performance over time.
#
# Machine learning works by training algorithms on large datasets, which allows them to identify patterns, relationships, and trends in the data. These algorithms can then use this information to make predictions, classify objects, and make decisions without being explicitly programmed.
#
# There are several key concepts in machine learning:
#
# 1. **Supervised learning

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful data science tutor."),
    ("human", "{question}")
])

chain = prompt | llm
result = chain.invoke({"question": "Explain gradient descent simply."})
print(result.content)
# Out:
# **What is Gradient Descent?**
#
# Gradient Descent is a fundamental concept in machine learning that helps algorithms find the best fit for a model. It's a simple yet powerful technique used to optimize the parameters of a model by iteratively adjusting them in the direction of the steepest descent.
#
# **The Idea Behind Gradient Descent**
#
# Imagine you're on a hill, and you want to get to the bottom as quickly as possible. You can't see the bottom, but you know that every step
